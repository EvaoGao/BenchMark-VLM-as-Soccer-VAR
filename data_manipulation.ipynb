# %%
# Merge three json files into one

import json

def merge_json_files(file1, file2, file3, output_file):
    merged_data = []

    for file in [file1, file2, file3]:
        with open(file, 'r', encoding='utf-8') as f:
            data = json.load(f)
            if isinstance(data, list):
                merged_data.extend(data)
            else:
                merged_data.append(data)

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(merged_data, f, ensure_ascii=False, indent=4)

# %%
if __name__ == "__main__":
    merge_json_files(
        "codes/soccerNet/annotations_test.json",
        "codes/soccerNet/annotations_train.json",
        "codes/soccerNet/annotations_valid.json",
        "combined_data.json"
    )

# %%
question1 = "Is it a foul or not? Why?"
question2 = "What card would you give? Why?"
question3 = "Could the referee have given advantage? Why?"

'''
Can not transform the text to lower case because capital 
letter contain information.
For example, 'No' must indicate false, 
but 'no' could appear in the explanation which may not means false.
'''

key1 = {"Yes":True, 
        "No":False, 
        "No foul":False,
        "No Foul":False, 
        "no foul":False,
        "Not a foul":False,
        "not a foul":False,
        "Not foul":False,
        "not foul":False,
        "yes":True}

key2 = {"Yellow": "Yellow", 
        "Red": "Red",
        "No card": "No card",
        "No Card": "No card",
        "no card": "No card",
        "No foul":"No card",
        "No Foul":"No card", 
        "no foul":"No card",
        "No":"No card",
        "yellow":"Yellow",
        "red":"Red",
        "Not a foul":"No card",
        "not a foul":"No card",
        "Not foul":"No card",
        "not foul":"No card"}

key3 = {"Yes":True,
        "No":False,
        "No advantage":False,
        "no advantage":False,
        "No Advantage":False,
        "yes":True,
        "No foul":False,
        "No Foul":False, 
        "no foul":False,
        "Not a foul":False,
        "not a foul":False,
        "Not foul":False,
        "not foul":False
        }

# %%
# Change the formatting of data to video-based

def transform_data(file, output_file):
    transformed_data = {}
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        for item in data:
            path = item.get("path", "")
            video1 = item.get("video1", "")
            video2 = item.get("video2", "")
            league = item.get("league", "")
            number_of_games = item.get("number_of_games", "")
            question = item.get("question", "")
            answer = item.get("answer", "")

            if path not in transformed_data:
                transformed_data[path] = {
                    "video1": video1,
                    "video2": video2,
                    "league": league,
                    "number_of_games": number_of_games,
                    "foul": [],
                    "card" : [],
                    "advantage": [],
                    "punishment": [],
                    "foul_explanation": [],
                    "card_explanation": [],
                    "advantage_explanation": [],
                    "punishment_explanation": []
                }
                if question == question1:
                    transformed_data[path]["foul_explanation"].append(answer)
                elif question == question2:
                    transformed_data[path]["card_explanation"].append(answer)
                elif question == question3:
                    transformed_data[path]["advantage_explanation"].append(answer)
            
            else:
                if not (video1 == transformed_data[path]["video1"] and
                        video2 == transformed_data[path]["video2"]):
                    print(f"Warning: Inconsistent video info for path {path}")

                if question == question1:
                    transformed_data[path]["foul_explanation"].append(answer)
                elif question == question2:
                    transformed_data[path]["card_explanation"].append(answer)
                elif question == question3:
                    transformed_data[path]["advantage_explanation"].append(answer)     

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(transformed_data, f, ensure_ascii=False, indent=4)

# %%
if __name__ == "__main__":
    transform_data("combined_data.json", "final_data.json")

# %%
# Use key words match to fill in the decision fields

def fill_in_decision(file):
    import re

    def match_whole_word(word, text):
        # Use regex to match whole words only
        pattern = rf'\b{re.escape(word)}\b'
        return re.search(pattern, text) is not None

    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        for path, value_dict in data.items():
            foul_explanations = value_dict.get("foul_explanation", [])
            card_explanations = value_dict.get("card_explanation", [])
            advantage_explanations = value_dict.get("advantage_explanation", [])

            for explanation in foul_explanations:
                all_match = []
                for key in key1:
                    if match_whole_word(key, explanation):
                        all_match.append(key1[key])

                set_all_match = set(all_match)
                if len(set_all_match) == 1:
                    value_dict["foul"].append(set_all_match.pop())
                else:
                    value_dict["foul"].append(None)
                
            for explanation in card_explanations:
                all_match = []
                for key in key2:
                    if match_whole_word(key, explanation):
                        all_match.append(key2[key])

                set_all_match = set(all_match)
                if len(set_all_match) == 1:
                    value_dict["card"].append(set_all_match.pop())
                else:
                    value_dict["card"].append(None)                       

            for explanation in advantage_explanations:
                all_match = []
                for key in key3:
                    if match_whole_word(key, explanation):
                        all_match.append(key3[key])

                set_all_match = set(all_match)
                if len(set_all_match) == 1:
                    value_dict["advantage"].append(set_all_match.pop())
                else:
                    value_dict["advantage"].append(None)

    with open("auto_labeled_data.json", 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
if __name__ == "__main__":
    fill_in_decision("final_data.json")

# %%
# Find data items with complete labels and export as complete_items_data.json

with open("auto_labeled_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
    count = 0
    complete_item_dict = {}
    for path, value_dict in data.items():
        foul = value_dict.get("foul", [])
        card = value_dict.get("card", [])   
        advantage = value_dict.get("advantage", [])
        if not (None in foul or None in card or None in advantage):
            count += 1
            complete_item_dict[path] = value_dict
    
    print(count)

with open("complete_items_data.json", 'w', encoding='utf-8') as f:
    json.dump(complete_item_dict, f, ensure_ascii=False, indent=4)
# Out:
# 1844

# %%
# Complete Consistent Data

with open("complete_items_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
    count = 0
    consistent_dict = {}
    for path, value_dict in data.items():
        foul = set(value_dict.get("foul", []))
        card = set(value_dict.get("card", [])) 
        advantage = set(value_dict.get("advantage", []))

        if len(foul)==1 and len(card)==1 and len(advantage)==1:
            count += 1
            consistent_dict[path] = value_dict
    
    print(count)

with open("complete_consistent_data.json", 'w', encoding='utf-8') as f:
    json.dump(consistent_dict, f, ensure_ascii=False, indent=4)
# Out:
# 1675

# %%
with open("complete_consistent_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
    count_no_foul = 0
    count_foul_no_card = 0
    count_yellow = 0
    count_red = 0
    count_advantage = 0

    balanced_dict = {}
    for path, value_dict in data.items():
        foul = value_dict.get("foul", [])
        card = value_dict.get("card", [])
        advantage = value_dict.get("advantage", [])

        if foul[0] == False and count_no_foul < 25:
            count_no_foul += 1
            balanced_dict[path] = value_dict
        elif advantage[0] == True and count_advantage < 8:
            count_advantage += 1
            balanced_dict[path] = value_dict
        elif foul[0] == True and card[0] == "No card" and count_foul_no_card < 9:
            count_foul_no_card += 1
            balanced_dict[path] = value_dict
        elif foul[0] == True and card[0] == "Yellow" and count_yellow < 8:
            count_yellow += 1
            balanced_dict[path] = value_dict
        elif foul[0] == True and card[0] == "Red" and count_red < 8:
            count_red += 1
            balanced_dict[path] = value_dict


with open("balanced_data.json", 'w', encoding='utf-8') as f:
    json.dump(balanced_dict, f, ensure_ascii=False, indent=4)

# %%
with open("complete_consistent_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)

    foul_dict = {}
    no_foul_dict = {}
    balanced_dict = {}
    for path, value_dict in data.items():
        foul = value_dict.get("foul", [])

        if foul[0] == False:
            no_foul_dict[path] = value_dict
        else:
            foul_dict[path] = value_dict
    
    no_foul_keys = list(no_foul_dict.keys())
    foul_keys = list(foul_dict.keys())
    for i in range(min(len(no_foul_dict),len(foul_dict))):
        balanced_dict[no_foul_keys[i]] = no_foul_dict[no_foul_keys[i]]
        balanced_dict[foul_keys[i]] = foul_dict[foul_keys[i]]

# half foul, half no foul
with open("balanced_data_2.json", 'w', encoding='utf-8') as f:
    json.dump(balanced_dict, f, ensure_ascii=False, indent=4)
    print(len(balanced_dict))
# Out:
# 522

# %%
# Check for duplicate keys in a JSON file
import json
from collections import Counter

def find_duplicate_keys(json_path: str):
    duplicates = Counter()

    def check_duplicates(pairs):
        keys = [k for k, _ in pairs]
        duplicates.update([k for k, count in Counter(keys).items() if count > 1])
        return dict(pairs) 

    with open(json_path, "r", encoding="utf-8") as f:
        json.load(f, object_pairs_hook=check_duplicates)

    if duplicates:
        print("[WARN] Found duplicate keys:")
        for key, count in duplicates.items():
            print(f"  '{key}' appears {count} times")
    else:
        print("[OK] No duplicate keys found.")

find_duplicate_keys("balanced_data_2.json")
# Out:
# [OK] No duplicate keys found.

# %%
with open("complete_consistent_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)

    foul_dict = {}
    for path, value_dict in data.items():
        foul = value_dict.get("foul", [])

        if foul[0] == True:
            foul_dict[path] = value_dict

with open("fouls_data.json", 'w', encoding='utf-8') as f:
    json.dump(foul_dict, f, ensure_ascii=False, indent=4)
    print(len(foul_dict))
# Out:
# 1444

# %%
with open("fouls_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
    num_no_card = 0
    num_yellow = 0
    num_red = 0
    no_card_paths = []
    yellow_paths = []
    red_paths = []
    balanced_dict = {}
    for path, value_dict in data.items():
        card = value_dict.get("card", [])
        if card[0] == "No card":
            num_no_card += 1
            no_card_paths.append(path)
        elif card[0] == "Yellow":
            num_yellow += 1
            yellow_paths.append(path)
        elif card[0] == "Red":
            num_red += 1
            red_paths.append(path)
    print(f"No card: {num_no_card}, Yellow: {num_yellow}, Red: {num_red}")

    for i in range(15):
        balanced_dict[no_card_paths[i]] = data[no_card_paths[i]]
        balanced_dict[yellow_paths[i]] = data[yellow_paths[i]]
        balanced_dict[red_paths[i]] = data[red_paths[i]]

with open("balanced_fouls_data.json", 'w', encoding='utf-8') as f:
    json.dump(balanced_dict, f, ensure_ascii=False, indent=4)
    print(len(balanced_dict))
# Out:
# No card: 934, Yellow: 487, Red: 23
# 45

# %%
with open("balanced_data.json", 'r', encoding='utf-8') as f:
    balanced_data = json.load(f)

with open("balanced_data_2.json", 'r', encoding='utf-8') as f:
    balanced_data_2 = json.load(f)

for test_data in balanced_data:
    if test_data in balanced_data_2:
        del balanced_data_2[test_data]

with open("train_foul.json", 'w', encoding='utf-8') as f:
    json.dump(balanced_data_2, f, ensure_ascii=False, indent=4)

# %%
with open("fouls_data.json", 'r', encoding='utf-8') as f:
    data = json.load(f)

    # Partition items by card type
    no_dict = {}
    yellow_dict = {}
    red_dict = {}
    for path, value_dict in data.items():
        card = value_dict.get("card", [])
        if not card:
            continue
        if card[0] == "No card":
            no_dict[path] = value_dict
        elif card[0] == "Yellow":
            yellow_dict[path] = value_dict
        elif card[0] == "Red":
            red_dict[path] = value_dict

import random
# Sample up to 100 items from no_dict and yellow_dict each (or all if fewer than 100)
no_keys = list(no_dict.keys())
yellow_keys = list(yellow_dict.keys())
sample_no = random.sample(no_keys, min(100, len(no_keys))) if no_keys else []
sample_yellow = random.sample(yellow_keys, min(100, len(yellow_keys))) if yellow_keys else []

# Construct the training dict: sampled no + sampled yellow + all red
train_dict = {}
for k in sample_no:
    train_dict[k] = no_dict[k]
for k in sample_yellow:
    train_dict[k] = yellow_dict[k]
# add all red items
for k, v in red_dict.items():
    train_dict[k] = v

print(f"Selected no_card: {len(sample_no)}, yellow: {len(sample_yellow)}, red: {len(red_dict)}. Total: {len(train_dict)}")

with open("train_card_adv.json", 'w', encoding='utf-8') as f:
    json.dump(train_dict, f, ensure_ascii=False, indent=4)
